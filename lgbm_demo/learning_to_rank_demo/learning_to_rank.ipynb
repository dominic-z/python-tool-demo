# %%
from sklearn import datasets as ds
import numpy as np
def load_data(feats, group):
    '''
    加载数据
    分别加载feature,label,query
    :param feats:
    :param group:
    :return:
    '''

    x_train, y_train = ds.load_svmlight_file(feats)
    q_train = np.loadtxt(group)

    return x_train, y_train, q_train

# %%
# !pwd
# Out:
# <function __main__.load_data(feats, group)>

# %%
feats_path='data/train/feats.txt'
group_path='data/train/group.txt'

x_train, y_train, q_train = load_data(feats_path,group_path)

# %%
x_train
# Out:
# <7796x46 sparse matrix of type '<class 'numpy.float64'>'
# 	with 358616 stored elements in Compressed Sparse Row format>

# %%
import lightgbm as lgb

train_data = lgb.Dataset(x_train, label=y_train, group=q_train)
params = {
    'task': 'train',  # 执行的任务类型
    'boosting_type': 'gbrt',  # 基学习器
    'objective': 'lambdarank',  # 排序任务(目标函数)
    'metric': 'ndcg',  # 度量的指标(评估函数)
    'max_position': 10,  # @NDCG 位置优化
    'metric_freq': 1,  # 每隔多少次输出一次度量结果
    'train_metric': True,  # 训练时就输出度量结果
    'ndcg_at': [10],
    'max_bin': 255,  # 一个整数，表示最大的桶的数量。默认值为 255。lightgbm 会根据它来自动压缩内存。如max_bin=255 时，则lightgbm 将使用uint8 来表示特征的每一个值。
    'num_iterations': 200,  # 迭代次数，即生成的树的棵数
    'learning_rate': 0.01,  # 学习率
    'num_leaves': 31,  # 叶子数
    # 'max_depth':6,
    'tree_learner': 'serial',  # 用于并行学习，‘serial’： 单台机器的tree learner
    'min_data_in_leaf': 30,  # 一个叶子节点上包含的最少样本数量
    'verbose': 2  # 显示训练时的信息
}
gbm = lgb.train(params, train_data, valid_sets=[train_data])
# Out:
# /Users/dominiczhu/opt/anaconda3/envs/PythonToolDemo/lib/python3.7/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Unknown parameter: max_position
# [LightGBM] [Warning] Unknown parameter: max_position
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.743757
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.391412
# [LightGBM] [Debug] init for col-wise cost 0.001598 seconds, init for row-wise cost 0.002496 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003937 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9171
# [LightGBM] [Info] Number of data points in the train set: 7796, number of used features: 40
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [1]	training's ndcg@10: 0.796443
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [2]	training's ndcg@10: 0.828216
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [3]	training's ndcg@10: 0.842904
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [4]	training's ndcg@10: 0.860481
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [5]	training's ndcg@10: 0.864379
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [6]	training's ndcg@10: 0.866419
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [7]	training's ndcg@10: 0.874243
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [8]	training's ndcg@10: 0.8773
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [9]	training's ndcg@10: 0.880492
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [10]	training's ndcg@10: 0.882798
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [11]	training's ndcg@10: 0.881241
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [12]	training's ndcg@10: 0.886561
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [13]	training's ndcg@10: 0.889016
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [14]	training's ndcg@10: 0.890494
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [15]	training's ndcg@10: 0.891963
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [16]	training's ndcg@10: 0.893055
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [17]	training's ndcg@10: 0.893112
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [18]	training's ndcg@10: 0.89671
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [19]	training's ndcg@10: 0.897216
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [20]	training's ndcg@10: 0.897545
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [21]	training's ndcg@10: 0.89858
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [22]	training's ndcg@10: 0.89883
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [23]	training's ndcg@10: 0.900091
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [24]	training's ndcg@10: 0.900849
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [25]	training's ndcg@10: 0.900933
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [26]	training's ndcg@10: 0.903587
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [27]	training's ndcg@10: 0.903859
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [28]	training's ndcg@10: 0.904357
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [29]	training's ndcg@10: 0.905168
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [30]	training's ndcg@10: 0.906051
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [31]	training's ndcg@10: 0.905426
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [32]	training's ndcg@10: 0.907063
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [33]	training's ndcg@10: 0.905956
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [34]	training's ndcg@10: 0.906264
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [35]	training's ndcg@10: 0.906979
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [36]	training's ndcg@10: 0.907037
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [37]	training's ndcg@10: 0.908108
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [38]	training's ndcg@10: 0.908434
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [39]	training's ndcg@10: 0.908104
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [40]	training's ndcg@10: 0.908815
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [41]	training's ndcg@10: 0.908976
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [42]	training's ndcg@10: 0.908799
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [43]	training's ndcg@10: 0.908989
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [44]	training's ndcg@10: 0.908928
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [45]	training's ndcg@10: 0.909443
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [46]	training's ndcg@10: 0.909723
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [47]	training's ndcg@10: 0.910594
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [48]	training's ndcg@10: 0.910978
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [49]	training's ndcg@10: 0.911243
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [50]	training's ndcg@10: 0.911098
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [51]	training's ndcg@10: 0.91113
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [52]	training's ndcg@10: 0.91095
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [53]	training's ndcg@10: 0.911407
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [54]	training's ndcg@10: 0.912008
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [55]	training's ndcg@10: 0.912149
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [56]	training's ndcg@10: 0.912524
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [57]	training's ndcg@10: 0.912415
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [58]	training's ndcg@10: 0.912483
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [59]	training's ndcg@10: 0.912763
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [60]	training's ndcg@10: 0.91293
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [61]	training's ndcg@10: 0.913118
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [62]	training's ndcg@10: 0.913444
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [63]	training's ndcg@10: 0.913875
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [64]	training's ndcg@10: 0.913999
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [65]	training's ndcg@10: 0.914355
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [66]	training's ndcg@10: 0.914764
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [67]	training's ndcg@10: 0.915072
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [68]	training's ndcg@10: 0.915577
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [69]	training's ndcg@10: 0.916652
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [70]	training's ndcg@10: 0.916771
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [71]	training's ndcg@10: 0.918265
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [72]	training's ndcg@10: 0.918072
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [73]	training's ndcg@10: 0.9178
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [74]	training's ndcg@10: 0.918411
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [75]	training's ndcg@10: 0.918826
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [76]	training's ndcg@10: 0.918692
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [77]	training's ndcg@10: 0.91888
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [78]	training's ndcg@10: 0.91917
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [79]	training's ndcg@10: 0.919648
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [80]	training's ndcg@10: 0.919724
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [81]	training's ndcg@10: 0.919917
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [82]	training's ndcg@10: 0.920129
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [83]	training's ndcg@10: 0.921049
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [84]	training's ndcg@10: 0.921345
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [85]	training's ndcg@10: 0.921706
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [86]	training's ndcg@10: 0.921554
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [87]	training's ndcg@10: 0.922437
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [88]	training's ndcg@10: 0.922953
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [89]	training's ndcg@10: 0.923285
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [90]	training's ndcg@10: 0.923493
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [91]	training's ndcg@10: 0.923591
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [92]	training's ndcg@10: 0.923912
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [93]	training's ndcg@10: 0.924576
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [94]	training's ndcg@10: 0.924447
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [95]	training's ndcg@10: 0.92434
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [96]	training's ndcg@10: 0.924615
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [97]	training's ndcg@10: 0.924763
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [98]	training's ndcg@10: 0.926083
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [99]	training's ndcg@10: 0.926176
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [100]	training's ndcg@10: 0.925907
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [101]	training's ndcg@10: 0.925968
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [102]	training's ndcg@10: 0.926895
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [103]	training's ndcg@10: 0.927646
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [104]	training's ndcg@10: 0.927752
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [105]	training's ndcg@10: 0.927701
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [106]	training's ndcg@10: 0.928125
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [107]	training's ndcg@10: 0.928496
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [108]	training's ndcg@10: 0.929141
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [109]	training's ndcg@10: 0.92879
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [110]	training's ndcg@10: 0.928806
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [111]	training's ndcg@10: 0.92833
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [112]	training's ndcg@10: 0.928637
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [113]	training's ndcg@10: 0.928709
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [114]	training's ndcg@10: 0.928941
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [115]	training's ndcg@10: 0.928915
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [116]	training's ndcg@10: 0.928659
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [117]	training's ndcg@10: 0.928531
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [118]	training's ndcg@10: 0.929357
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [119]	training's ndcg@10: 0.929587
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [120]	training's ndcg@10: 0.929681
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [121]	training's ndcg@10: 0.929779
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [122]	training's ndcg@10: 0.930167
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [123]	training's ndcg@10: 0.930265
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [124]	training's ndcg@10: 0.930409
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [125]	training's ndcg@10: 0.93074
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [126]	training's ndcg@10: 0.930003
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [127]	training's ndcg@10: 0.930234
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [128]	training's ndcg@10: 0.930041
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [129]	training's ndcg@10: 0.930309
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [130]	training's ndcg@10: 0.931218
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [131]	training's ndcg@10: 0.931246
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [132]	training's ndcg@10: 0.930936
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [133]	training's ndcg@10: 0.93144
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [134]	training's ndcg@10: 0.931373
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [135]	training's ndcg@10: 0.93157
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [136]	training's ndcg@10: 0.931542
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [137]	training's ndcg@10: 0.931726
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [138]	training's ndcg@10: 0.931844
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [139]	training's ndcg@10: 0.931986
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [140]	training's ndcg@10: 0.932008
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [141]	training's ndcg@10: 0.932091
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [142]	training's ndcg@10: 0.932285
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [143]	training's ndcg@10: 0.932368
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [144]	training's ndcg@10: 0.93281
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [145]	training's ndcg@10: 0.932702
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [146]	training's ndcg@10: 0.933033
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [147]	training's ndcg@10: 0.933665
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [148]	training's ndcg@10: 0.933731
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [149]	training's ndcg@10: 0.934032
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [150]	training's ndcg@10: 0.934062
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [151]	training's ndcg@10: 0.934431
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [152]	training's ndcg@10: 0.934674
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [153]	training's ndcg@10: 0.935144
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [154]	training's ndcg@10: 0.935198
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [155]	training's ndcg@10: 0.935627
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [156]	training's ndcg@10: 0.935696
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [157]	training's ndcg@10: 0.935603
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [158]	training's ndcg@10: 0.935744
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [159]	training's ndcg@10: 0.935857
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [160]	training's ndcg@10: 0.935968
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [161]	training's ndcg@10: 0.936144
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [162]	training's ndcg@10: 0.936287
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [163]	training's ndcg@10: 0.936277
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [164]	training's ndcg@10: 0.93644
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [165]	training's ndcg@10: 0.936383
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [166]	training's ndcg@10: 0.936538
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [167]	training's ndcg@10: 0.936287
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [168]	training's ndcg@10: 0.936744
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 18
# [169]	training's ndcg@10: 0.936973
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [170]	training's ndcg@10: 0.937088
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [171]	training's ndcg@10: 0.937338
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [172]	training's ndcg@10: 0.93755
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [173]	training's ndcg@10: 0.937663
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [174]	training's ndcg@10: 0.93768
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [175]	training's ndcg@10: 0.937793
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [176]	training's ndcg@10: 0.937673
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [177]	training's ndcg@10: 0.938286
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [178]	training's ndcg@10: 0.938452
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [179]	training's ndcg@10: 0.938634
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 19
# [180]	training's ndcg@10: 0.940182
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [181]	training's ndcg@10: 0.940025
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [182]	training's ndcg@10: 0.940708
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [183]	training's ndcg@10: 0.94052
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [184]	training's ndcg@10: 0.941082
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [185]	training's ndcg@10: 0.94114
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [186]	training's ndcg@10: 0.941341
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [187]	training's ndcg@10: 0.941541
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [188]	training's ndcg@10: 0.941434
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [189]	training's ndcg@10: 0.941445
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [190]	training's ndcg@10: 0.94152
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [191]	training's ndcg@10: 0.941775
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [192]	training's ndcg@10: 0.941784
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [193]	training's ndcg@10: 0.942398
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [194]	training's ndcg@10: 0.942431
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [195]	training's ndcg@10: 0.942998
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [196]	training's ndcg@10: 0.94313
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [197]	training's ndcg@10: 0.943133
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [198]	training's ndcg@10: 0.943332
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [199]	training's ndcg@10: 0.943126
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [200]	training's ndcg@10: 0.943867

# %%
"""

Various utilities for converting data from/to Microsoft's LETOR format.

"""

import numpy as np
# import sklearn.externals.six

def iter_lines(lines, has_targets=True, one_indexed=True, missing=0.0):
    """Transforms an iterator of lines to an iterator of LETOR rows.

    Each row is represented by a (x, y, qid, comment) tuple.

    Parameters
    ----------
    lines : iterable of lines
        Lines to parse.
    has_targets : bool, optional
        Whether the file contains targets. If True, will expect the first token
        of every line to be a real representing the sample's target (i.e.
        score). If False, will use -1 as a placeholder for all targets.
    one_indexed : bool, optional 特征id从1开始的转为从0开始
        Whether feature ids are one-indexed. If True, will subtract 1 from each
        feature id.
    missing : float, optional
        Placeholder to use if a feature value is not provided for a sample.

    Yields
    ------
    x : array of floats
        Feature vector of the sample.
    y : float
        Target value (score) of the sample, or -1 if no target was parsed.
    qid : object
        Query id of the sample. This is currently guaranteed to be a string.
    comment : str
        Comment accompanying the sample.

    """
    for line in lines:
        data, _, comment = line.rstrip().partition('#')
        toks = data.strip().split()
        # toks = line.rstrip()
        # toks = re.split('\s+', toks.strip())
        # print("toks: ", toks)
        # comment = "no comment"
        num_features = 0  # 统计特征个数
        x = np.repeat(missing, 8)
        y = -1.0
        if has_targets:
            y = float(toks[0].strip())  # 相关度label
            toks = toks[1:]
        # qid:1 => 1
        qid = _parse_qid_tok(toks[0].strip())

        # feature(id:value)
        for tok in toks[1:]:
            # fid, _, val = tok.strip().partition(':') # fid,_,val => featureID,:,featureValue
            fid, val = tok.split(":")  # featureID:featureValue
            fid = int(fid)
            val = float(val)
            if one_indexed:
                fid -= 1
            assert fid >= 0
            while len(x) <= fid:
                orig = len(x)
                # x=np.resize(x,(len(x) * 2))
                x.resize(len(x) * 2)
                x[orig:orig * 2] = missing
            x[fid] = val
            num_features = max(fid + 1, num_features)

        assert num_features > 0
        x.resize(num_features)

        yield (x, y, qid, comment)


def read_dataset(source, has_targets=True, one_indexed=True, missing=0.0):
    """Parses a LETOR dataset from `source`.

    Parameters
    ----------
    source : string or iterable of lines
        String, file, or other file-like object to parse.
    has_targets : bool, optional
        See `iter_lines`.
    one_indexed : bool, optional
        See `iter_lines`.
    missing : float, optional
        See `iter_lines`.

    Returns
    -------
    X : array of arrays of floats
      Feature matrix (see `iter_lines`).
    y : array of floats
        Target vector (see `iter_lines`).
    qids : array of objects
        Query id vector (see `iter_lines`).
    comments : array of strs
        Comment vector (see `iter_lines`).
    """
    # if isinstance(source, sklearn.externals.six.string_types):
    #     source = source.splitlines(True)

    max_width = 0  # 某行最多特征个数
    xs, ys, qids, comments = [], [], [], []
    iter_content = iter_lines(source, has_targets=has_targets,
                              one_indexed=one_indexed, missing=missing)
    # x:特征向量; y:float 相关度值[0-4]; qid:string query id; comment: #后面内容
    for x, y, qid, comment in iter_content:
        xs.append(x)
        ys.append(y)
        qids.append(qid)
        comments.append(comment)
        max_width = max(max_width, len(x))

    assert max_width > 0
    # X.shape = [len(xs), max_width]
    X = np.ndarray((len(xs), max_width), dtype=np.float64)
    X.fill(missing)
    for i, x in enumerate(xs):
        X[i, :len(x)] = x
    ys = np.array(ys) if has_targets else None
    qids = np.array(qids)
    comments = np.array(comments)

    return (X, ys, qids, comments)


def _parse_qid_tok(tok):
    assert tok.startswith('qid:')
    return tok[4:]

# %%
test_path='data/test/test.txt'

with open(test_path, 'r', encoding='utf-8') as testfile:
    test_X, test_y, test_qids, comments = read_dataset(testfile)

# %%
pre_y=gbm.predict(test_X)

# %%
pre_y
# Out:
# array([ 8.28653643e-01, -1.84790338e+00,  6.28460133e-01,  3.88748943e-01,
#        -1.82119377e-01, -5.97297350e-01, -1.87969974e+00, -1.85166921e+00,
#        -1.75601130e+00, -1.12507393e+00, -2.04025694e-01,  6.13358850e-02,
#         4.43838050e-01, -1.38145962e+00, -3.31403080e-01, -7.14954979e-01,
#        -1.45957587e+00,  1.93886930e-01,  7.50698640e-02, -1.75601130e+00,
#        -6.60452370e-01, -6.20252554e-01, -1.87550818e+00, -1.70558595e+00,
#        -1.54403456e+00, -1.87338586e+00, -1.41958973e+00,  4.62068713e-01,
#        -1.59909283e+00,  2.71303457e-01,  4.74996309e-01, -1.39975685e+00,
#        -1.17611961e+00, -1.37615695e-01, -1.34400010e+00, -1.11060853e+00,
#         4.77172281e-02, -1.87550818e+00, -8.47657388e-01, -1.87550818e+00,
#         4.61301112e-01, -1.87550818e+00, -6.28599839e-01, -3.46319451e-01,
#         2.55898846e-01,  1.75989083e-01,  1.10848328e-01, -5.51663064e-01,
#         2.68132528e-01,  8.02965697e-03, -4.51652997e-01, -9.35367832e-02,
#        -2.56032322e-01, -4.27350867e-01,  3.46441938e-01, -1.87969974e+00,
#        -6.93077250e-01, -1.28580691e+00,  2.69583425e-02, -1.87550818e+00,
#        -1.53253761e+00, -8.27705439e-01, -1.87969974e+00,  8.67799339e-01,
#        -1.66115164e+00,  4.61296256e-01, -1.87550818e+00, -1.47160036e+00,
#         2.10721574e-01,  9.42677913e-01, -1.87969974e+00, -1.09356712e+00,
#        -7.38179581e-01, -8.30454143e-01, -1.13669348e-01,  8.44600905e-01,
#        -1.74086103e+00,  6.34753068e-01, -9.09169049e-01, -9.40963163e-01,
#         5.45030104e-01, -3.30973011e-01, -7.85004055e-01, -1.64920897e+00,
#        -1.34410292e+00, -1.01733193e+00, -3.15476672e-01,  2.97008503e-01,
#         1.70402997e-01, -1.06417807e+00, -1.58239178e+00, -1.75118148e+00,
#         8.71267798e-01, -1.86930495e+00,  2.13572817e-02,  5.49647673e-01,
#         1.11057134e-01, -1.77465771e+00,  1.83770648e-01, -5.89456511e-01,
#        -1.73565862e+00, -1.68765177e+00, -8.35259340e-01, -1.73965149e+00,
#         7.91675179e-01, -1.77189366e+00,  5.44076306e-01, -1.86930495e+00,
#        -1.79833551e+00, -6.93615209e-01, -1.04170288e+00,  4.53294304e-01,
#        -1.02094669e+00,  3.46074819e-01,  5.15751942e-01, -1.87969974e+00,
#         5.22445526e-01, -1.59714562e-01, -8.79912412e-03, -2.88576246e-01,
#         1.69108965e-01, -1.86930495e+00, -4.74432885e-01,  6.94411063e-01,
#        -1.86930495e+00,  2.66638300e-02, -1.70003136e+00,  6.21473453e-01,
#        -1.85166921e+00, -1.52869503e+00, -7.47139320e-01,  1.53124067e-01,
#         2.57464459e-01, -1.81153915e-01, -4.09160826e-01, -1.19957527e+00,
#        -1.46183766e-01, -6.50831087e-01, -1.87969974e+00, -1.84790338e+00,
#        -5.59214636e-01, -1.47731476e+00,  3.76582104e-01, -9.47487149e-02,
#        -1.85166921e+00,  4.80325183e-01, -1.22147673e+00, -1.30287232e+00,
#         2.46489415e-01, -1.17533151e+00, -1.53295401e+00, -1.26353539e+00,
#         2.82128153e-01, -1.85166921e+00, -8.47206090e-01, -8.96300798e-01,
#         7.40050827e-02, -3.07340493e-03,  1.45507946e-01, -1.61554246e+00,
#        -1.46845357e+00,  8.36890061e-01, -8.18935815e-02, -1.86930495e+00,
#         3.49301026e-01,  1.65139817e-01, -1.85166921e+00, -1.48163109e+00,
#        -1.85166921e+00, -4.08673113e-01, -4.67090909e-02, -4.68117603e-01,
#        -1.84979343e+00,  4.01396292e-01,  2.26642040e-01,  7.67940058e-02,
#        -1.85166921e+00,  1.05036134e-01,  4.03793977e-01, -1.87969974e+00,
#        -1.84790338e+00, -3.72029962e-01,  1.25441148e-01, -1.40887043e-01,
#        -8.28889582e-01,  3.54131967e-01, -1.85166921e+00, -1.70192141e+00,
#        -8.95026034e-01,  6.82896997e-01, -1.51599572e+00,  5.81637347e-01,
#        -9.03695014e-01, -9.17300815e-01, -1.71051704e+00, -7.71472101e-01,
#        -1.85166921e+00,  1.87141630e-01, -1.69832848e+00, -3.55932352e-01,
#         6.20287126e-01, -1.39587992e+00, -3.67253674e-01, -7.15376102e-01,
#        -9.20010901e-01,  4.11283774e-02,  5.49104078e-01, -9.78160437e-02,
#        -7.99036422e-01, -7.21726408e-01, -1.79342214e+00,  7.30990526e-01,
#        -1.85166921e+00, -3.79583973e-01, -2.51226453e-02,  9.48178697e-01,
#        -5.82033638e-01, -1.85166921e+00, -9.53138240e-01, -4.80848663e-01,
#        -2.53660544e-01, -4.37481218e-01, -1.39260219e+00,  4.13890668e-01,
#        -6.03636342e-01, -3.58438510e-01, -1.28339263e+00, -1.45113741e+00,
#        -3.76752446e-02,  1.96847606e-01, -4.74289516e-01, -1.91668041e-01,
#        -1.18429542e+00, -6.51037858e-01, -1.87550818e+00, -1.74517771e-01,
#         1.29287324e-01, -9.81544472e-01,  4.68419074e-01, -1.34565899e+00,
#        -4.00763533e-01, -1.65637666e+00, -1.87661448e+00, -3.83811782e-02,
#        -1.16075238e+00, -1.66781979e+00, -1.14433528e+00,  1.13938316e+00,
#        -1.19937997e+00, -1.85166921e+00,  4.13657738e-02, -1.75661439e+00,
#         4.33090660e-01, -6.21546385e-01, -2.98141423e-02, -1.84979343e+00,
#        -1.12461054e+00, -2.41485648e-01, -3.94786473e-01, -4.98790815e-01,
#        -7.83601433e-02, -7.89914350e-02, -1.84751085e+00, -6.42924840e-01,
#         6.66479247e-01, -2.15608111e-01, -1.85658259e+00,  7.95260882e-01,
#         1.88680660e-01, -1.78007861e+00, -1.70286980e+00, -1.35000910e+00,
#         2.52080405e-01, -1.58602115e+00, -1.89577595e-01, -1.85658259e+00,
#        -5.12896325e-01, -9.09381081e-01, -1.06186707e+00,  3.19632868e-01,
#         5.20384911e-01,  5.25968784e-01,  2.25898751e-01, -1.87969974e+00,
#         4.92132633e-01,  2.93716082e-01,  2.18703203e-01, -1.86930495e+00,
#        -1.73316509e+00, -1.71301382e+00,  6.59929371e-01, -4.16507884e-02,
#         8.76541867e-01, -3.97822605e-01, -1.87550818e+00, -5.30410437e-01,
#        -1.69500484e+00, -1.72324530e+00, -1.37095384e+00,  3.93048818e-01,
#        -3.38242732e-01, -1.87550818e+00, -1.65981205e+00, -8.60677059e-01,
#        -9.66416358e-01, -3.79599797e-01, -3.33005731e-01,  5.34797133e-01,
#        -1.86600423e+00, -1.66431551e+00,  7.09560600e-01, -1.20859935e-01,
#        -1.87550818e+00,  4.61029296e-01, -7.26797389e-01, -2.69998227e-01,
#        -2.28067498e-01, -1.75674252e+00, -9.53930994e-01,  3.51930030e-01,
#        -5.24981806e-01, -1.26148555e+00, -9.03434193e-01,  2.40045672e-01,
#        -1.10118215e+00,  5.30177521e-01, -1.36212445e+00, -1.01119121e+00,
#        -1.39314442e+00, -1.28812672e+00, -2.67317375e-03,  4.82886500e-02,
#        -3.15164807e-01, -2.20599951e-01, -8.51247135e-01, -1.85166921e+00,
#        -3.88477253e-01, -6.39979188e-01,  9.60351904e-02, -9.44975869e-02,
#         1.21501897e-03, -4.90054751e-02,  9.78318685e-01,  5.38158870e-01,
#         1.91489499e-01, -1.97430390e-01, -1.87550818e+00, -1.80418483e+00,
#        -9.90896773e-01, -1.86553912e+00,  1.22932792e-01,  4.31570185e-01,
#         5.51308599e-01, -7.48679749e-01, -1.41925106e-01,  3.95305409e-02,
#         3.85538820e-01, -1.15329218e+00, -1.02180140e+00,  5.12087783e-01,
#        -1.42166690e+00, -1.74380354e+00,  2.62111428e-01,  4.68625388e-01,
#        -6.25542064e-01,  5.74382952e-01,  6.73254836e-01,  4.87230849e-01,
#        -1.87969974e+00, -3.09526550e-01,  5.06298113e-01, -6.07060075e-01,
#        -6.42181225e-01, -6.33128511e-01,  4.27583196e-01,  3.36606310e-01,
#        -6.77428915e-01, -7.54660951e-02, -1.60395916e+00, -4.96143346e-01,
#        -1.85166921e+00,  5.82371908e-01,  2.59410745e-01, -1.55550180e+00,
#         1.55485353e-01, -1.49862850e-02,  4.14346936e-01,  8.35763494e-01,
#        -1.85166921e+00,  4.79664215e-01, -1.74635558e+00, -1.79342214e+00,
#         2.54947787e-01,  3.34779629e-01, -1.77063648e+00, -1.85166921e+00,
#        -1.85166921e+00, -1.29759361e-01, -1.96171479e-01,  1.13160830e-01,
#        -1.86930495e+00, -5.49826894e-01, -1.75345926e+00, -1.22430582e-01,
#        -4.36572380e-01, -1.85166921e+00,  2.33521873e-01, -3.42002313e-01,
#        -1.86930495e+00, -8.13084649e-01,  4.20887889e-01,  3.83984741e-01,
#         5.83643943e-01,  4.09153446e-01, -8.54989763e-01, -1.04897279e+00,
#         1.64901135e-01, -3.55955784e-01, -5.22214787e-02, -2.01872039e-02,
#         1.99057505e-02,  5.89024512e-01,  2.36215811e-01,  5.08739657e-01,
#         2.89743149e-01,  3.66742723e-01,  3.65511954e-01,  2.45402065e-01,
#        -1.85166921e+00,  1.86364115e-01, -1.11280856e+00, -9.63141207e-01,
#        -2.14484343e-02, -9.71980233e-01,  7.91631221e-01,  5.40047776e-01,
#        -4.64244498e-02, -1.70054455e-01, -1.62482789e-01, -1.87550818e+00,
#        -1.00236222e+00, -6.31953893e-01, -6.18231251e-01, -1.87550818e+00,
#        -1.19437301e+00, -2.89469444e-01, -3.04009213e-01, -4.94097319e-01,
#        -5.07506419e-01, -5.27760332e-01, -1.72503575e+00,  1.21885506e-01,
#        -1.12003102e+00, -8.61118692e-01,  6.88448209e-01, -1.22796644e+00,
#         6.51721964e-01, -6.82823737e-01, -1.28337003e+00, -1.11235888e+00,
#        -2.02895244e-01, -4.65029613e-01, -3.13913203e-01, -4.11158612e-01,
#        -7.16137528e-01, -1.40173563e+00, -1.40173563e+00,  1.87020581e-01,
#        -1.87550818e+00, -1.87550818e+00,  2.52368090e-01, -1.14119267e+00,
#        -1.87550818e+00, -1.09599636e-01, -9.19844687e-01, -1.87550818e+00,
#        -1.87550818e+00, -1.87550818e+00, -1.87969974e+00, -1.86474155e+00,
#        -2.95142216e-01, -2.74763677e-01, -9.39614191e-01, -4.82683757e-01,
#        -1.87550818e+00, -1.87550818e+00, -1.87550818e+00,  1.55597255e-01,
#        -1.56282041e+00, -1.87550818e+00, -1.54987662e+00, -2.37126599e-01,
#        -1.86218297e+00, -1.00547267e+00,  2.89373862e-01, -4.10403349e-01,
#         1.08594565e+00, -1.02227060e+00, -7.54102405e-01, -2.50613613e-01,
#        -6.63208110e-01,  5.18215421e-01, -6.09353755e-01, -1.86218297e+00,
#        -3.73498294e-01, -1.63556436e+00, -3.40506845e-01, -2.44932169e-01,
#        -1.45144754e+00, -1.76974433e+00, -5.38330584e-01, -1.65154079e+00,
#        -1.13655525e-01, -1.86930495e+00, -1.76974433e+00, -1.18804099e-01,
#        -5.11089649e-01,  1.44373599e-01,  4.37846292e-01,  8.99852936e-01,
#         8.99280952e-03, -1.27030349e+00, -1.34612158e+00, -1.21893162e-01,
#        -1.14870022e-01, -1.87969974e+00, -8.38165131e-01, -1.86718263e+00,
#        -8.39068414e-02, -1.25391978e+00, -1.19375379e+00, -5.06741624e-01,
#        -1.67901175e+00, -1.87550818e+00, -3.47096528e-01, -3.04401865e-01,
#         1.12846571e-01, -2.47282627e-01,  6.37892031e-01,  1.51584543e-01,
#        -1.62784524e+00, -1.74169859e+00, -1.10867230e+00,  1.59331051e-01,
#        -1.19344726e+00, -1.25585961e+00, -1.87550818e+00, -1.44559874e+00,
#        -1.62446497e+00,  3.55439709e-01,  3.82672602e-01, -1.08506071e+00,
#        -7.54702353e-01, -1.87550818e+00,  6.66727700e-01, -1.30363698e+00,
#        -1.87550818e+00, -1.52665065e-01, -1.45677379e+00, -1.87111732e+00,
#        -8.88895328e-01, -7.89582199e-01, -5.47683777e-01, -2.90687105e-01,
#        -7.24121346e-01,  2.25831837e-01, -6.35997380e-01, -1.10644179e+00,
#        -1.25937531e+00, -5.42388976e-01,  5.54844045e-01, -1.87550818e+00,
#        -1.87969974e+00, -9.92622849e-01, -1.87550818e+00,  1.30294578e-01,
#        -1.87550818e+00, -1.99084320e-01, -7.28758858e-01,  4.50603857e-01,
#         1.85453361e-01, -1.87550818e+00, -9.64608276e-01, -6.52936964e-01,
#        -1.12550110e+00, -2.98857272e-01, -1.11318804e-01, -3.16787944e-01,
#        -1.87550818e+00,  3.42484671e-02,  1.55757035e-01, -6.02748082e-01,
#        -1.70040610e+00, -9.48747225e-01,  4.43637429e-02, -1.53960423e+00,
#         1.06258344e-01, -1.42341298e-01, -1.87550818e+00, -4.73322780e-01,
#        -7.82524726e-02, -1.87550818e+00, -1.03598971e+00, -1.87338586e+00,
#        -3.94596749e-01, -1.36003474e+00,  2.83525188e-01, -7.41932934e-01,
#         4.27353238e-01, -2.52941330e-01, -1.59824709e+00, -1.87550818e+00,
#        -1.86553912e+00, -1.26104015e+00, -3.59712676e-01, -1.87969974e+00,
#        -1.30235938e+00, -6.07236199e-01, -1.61668423e-01, -1.33381913e-01,
#         9.96576491e-01, -1.87969974e+00, -6.66235704e-01, -1.85166921e+00,
#        -1.85658259e+00, -1.83041928e+00, -1.68038250e+00, -1.85658259e+00,
#        -1.62088500e+00, -1.85658259e+00,  3.09245495e-01,  3.09245495e-01,
#         3.23210351e-01,  3.23210351e-01,  3.23210351e-01,  3.49672544e-01,
#         3.09245495e-01, -1.83893734e+00, -2.37582725e-01,  6.07940194e-01,
#        -1.85658259e+00,  7.49016569e-02, -1.87969974e+00, -7.14346612e-01,
#        -5.53179545e-01, -1.85658259e+00,  8.36898616e-02, -1.73193811e-02,
#        -1.26515641e+00, -2.32946086e-01,  5.66558041e-01, -1.43911405e+00,
#        -1.86930495e+00, -1.45258041e+00, -5.63686970e-01,  6.09830076e-01,
#        -8.45653778e-02, -1.36468242e+00, -7.74345251e-01, -1.49220441e+00,
#         3.80956484e-01, -6.66540112e-01, -1.51880350e+00, -4.42009818e-01,
#        -9.20698370e-01, -6.63663474e-01,  2.47420008e-01, -4.51992449e-01,
#        -1.40266592e+00, -5.66641394e-01, -1.69046880e+00, -4.77035159e-01,
#         2.18351198e-01,  6.27455669e-02, -4.39633640e-01,  2.32599822e-01,
#        -1.46902139e+00, -1.87550818e+00, -2.95269386e-01, -3.06841015e-01,
#        -8.87925712e-01, -1.87174235e+00, -1.87550818e+00, -1.87550818e+00,
#        -1.87550818e+00, -1.87550818e+00, -9.84239661e-01, -1.05108129e+00,
#        -1.02089096e+00, -1.25696215e+00, -7.63623707e-01, -9.26170050e-01,
#        -1.55340453e+00, -1.02572752e+00,  7.22901408e-01, -1.00729793e+00,
#         4.60771525e-01, -1.87550818e+00, -8.13100053e-01,  4.06543270e-01,
#        -1.87550818e+00, -6.36499571e-01, -1.87550818e+00, -1.87550818e+00,
#        -1.26821868e+00,  5.31089449e-02, -1.87550818e+00,  2.84984144e-02,
#        -4.25110578e-01, -1.69549272e+00, -1.51606161e+00,  5.46357510e-01,
#         4.24094291e-01,  3.53403308e-01, -1.86930495e+00, -1.87550818e+00,
#        -1.87550818e+00, -2.50985761e-01, -8.85003511e-01, -5.17862359e-01,
#        -1.87550818e+00, -1.87550818e+00, -1.87550818e+00, -1.87550818e+00,
#        -1.56228258e+00, -6.54524551e-01,  1.61332223e-01, -1.86474155e+00,
#         1.73084510e-01,  1.85177485e-01, -4.43137532e-01, -5.32997075e-01,
#        -4.67575054e-01, -1.71470637e+00, -1.20352180e+00, -9.99980260e-01,
#        -1.39122216e+00, -1.87550818e+00, -8.80869723e-01, -1.87550818e+00,
#        -1.80918842e-01, -9.34066770e-02, -7.21869632e-01, -4.96217852e-01,
#        -1.44390669e+00, -7.04102953e-01,  3.36900959e-02,  2.52907664e-01,
#        -6.38882157e-01,  1.35523655e-01, -1.87550818e+00, -1.70421956e+00,
#        -1.69648570e+00, -1.07783439e+00, -3.16324360e-01, -2.72128609e-01,
#        -1.87550818e+00, -3.88693334e-01, -3.69936461e-01, -7.83370441e-02,
#        -3.10978451e-01, -9.39745975e-01, -1.24535589e-01,  4.04737170e-01,
#        -3.48773465e-01, -1.87550818e+00, -3.61203126e-01, -2.04313549e-01,
#        -1.43612547e+00, -5.49034338e-01, -1.25483183e-01, -1.39097156e+00,
#        -6.82200757e-01, -1.85166921e+00, -1.85166921e+00, -3.83359411e-01,
#         2.05757811e-01, -1.44370303e+00, -1.47022795e+00,  2.30776312e-01,
#        -1.74570327e+00,  6.52262186e-01,  5.15613593e-01,  6.43788789e-01,
#        -1.86930495e+00, -1.65574949e+00, -1.54544787e+00, -1.85166921e+00,
#        -1.71977362e+00, -3.20534409e-01,  1.01474284e+00, -1.85166921e+00,
#        -1.85166921e+00, -1.43314293e+00, -7.25455060e-01])
