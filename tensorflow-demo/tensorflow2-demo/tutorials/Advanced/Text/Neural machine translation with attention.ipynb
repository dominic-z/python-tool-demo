# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %%
# Download the file
path_to_zip = tf.keras.utils.get_file(
    'spa-eng.zip', origin='http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip',
    extract=True)

path_to_file = .dirname(path_to_zip)+"/spa-eng/spa.txt"

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
en_sentence = u"May I borrow this book?"
sp_sentence = u"¿Puedo tomar prestado este libro?"
print(preprocess_sentence(en_sentence))
print(preprocess_sentence(sp_sentence).encode('utf-8'))
# Out:
# <start> may i borrow this book ? <end>
# b'<start> \xc2\xbf puedo tomar prestado este libro ? <end>'

# %%
s = 'bla. bla? bla.bla! bla...'
import re
s = re.sub('([.,!?()])', r' \1 ', s)
print(s)
s = re.sub('\s{2,}', ' ', s)
print(s)
# Out:
# bla .  bla ?  bla . bla !  bla .  .  .
# bla . bla ? bla . bla ! bla . . .

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENGLISH, SPANISH]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, sp = create_dataset(path_to_file, None)
print(en[-1])
print(sp[-1])
# Out:
# <start> if you want to sound like a native speaker , you must be willing to practice saying the same sentence over and over in the same way that banjo players practice the same phrase over and over until they can play it correctly and at the desired tempo . <end>
# <start> si quieres sonar como un hablante nativo , debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un musico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado . <end>

# %%
# 英文和西班牙语是通过\t分割的
lines = io.open(path_to_file, encoding='UTF-8').read().strip().split('\n')
lines[:None]
# Out:
# ['Go.\tVe.',
#  'Go.\tVete.',
#  'Go.\tVaya.',
#  'Go.\tVáyase.',
#  'Hi.\tHola.',
#  'Run!\t¡Corre!',
#  'Run.\tCorred.',
#  'Who?\t¿Quién?',
#  'Fire!\t¡Fuego!',
#  'Fire!\t¡Incendio!',
#  'Fire!\t¡Disparad!',
#  'Help!\t¡Ayuda!',
#  'Help!\t¡Socorro! ¡Auxilio!',
#  'Help!\t¡Auxilio!',
#  'Jump!\t¡Salta!',
#  'Jump.\tSalte.',
#  'Stop!\t¡Parad!',
#  'Stop!\t¡Para!',
#  'Stop!\t¡Pare!',
#  'Wait!\t¡Espera!',
#  'Wait.\tEsperen.',
#  'Go on.\tContinúa.',
#  'Go on.\tContinúe.',
#  'Hello!\tHola.',
#  'I ran.\tCorrí.',
#  'I ran.\tCorría.',
#  'I try.\tLo intento.',
#  'I won!\t¡He ganado!',
#  'Oh no!\t¡Oh, no!',
#  'Relax.\tTomátelo con soda.',
#  'Smile.\tSonríe.',
#  'Attack!\t¡Al ataque!',
#  'Attack!\t¡Atacad!',
#  'Get up.\tLevanta.',
#  'Go now.\tVe ahora mismo.',
#  'Got it!\t¡Lo tengo!',
#  'Got it?\t¿Lo pillas?',
#  'Got it?\t¿Entendiste?',
#  'He ran.\tÉl corrió.',
#  'Hop in.\tMétete adentro.',
#  'Hug me.\tAbrázame.',
#  'I fell.\tMe caí.',
#  'I know.\tYo lo sé.',
#  'I left.\tSalí.',
#  'I lied.\tMentí.',
#  'I lost.\tPerdí.',
#  'I quit.\tDimito.',
#  'I quit.\tRenuncié.',
#  'I work.\tEstoy trabajando.',
#  "I'm 19.\tTengo diecinueve.",
#  "I'm up.\tEstoy levantado.",
#  'Listen.\tEscucha.',
#  'Listen.\tEscuche.',
#  'Listen.\tEscuchen.',
#  'No way!\t¡No puede ser!',
#  'No way!\tDe ninguna manera.',
#  'No way!\t¡De ninguna manera!',
#  'No way!\t¡Imposible!',
#  'No way!\t¡De ningún modo!',
#  'No way!\t¡De eso nada!',
#  'No way!\t¡Ni cagando!',
#  'No way!\t¡Mangos!',
#  'No way!\t¡Minga!',
#  'No way!\t¡Ni en pedo!',
#  'Really?\t¿En serio?',
#  'Really?\t¿La verdad?',
#  'Thanks.\t¡Gracias!',
#  'Thanks.\tGracias.',
#  'Try it.\tPruébalo.',
#  'We try.\tLo procuramos.',
#  'We won.\tGanamos.',
#  'Why me?\t¿Por qué yo?',
#  'Ask Tom.\tPregúntale a Tom.',
#  'Awesome!\t¡Órale!',
#  'Be calm.\tMantente en calma.',
#  'Be cool.\tEstate tranquilo.',
#  'Be fair.\tSé justo.',
#  'Be kind.\tSean gentiles.',
#  'Be nice.\tSé agradable.',
#  'Beat it.\tPírate.',
#  'Call me.\tLlamame.',
#  'Call me.\tLlamadme.',
#  'Call me.\tLlámame.',
#  'Call us.\tLlámanos.',
#  'Come in.\tEntre.',
#  'Come in.\tPase.',
#  'Come in.\t¡Entren!',
#  'Come on!\t¡Órale!',
#  'Come on.\tÁndale.',
#  'Come on.\t¡Órale!',
#  'Drop it!\tSuéltalo.',
#  'Get Tom.\tAgarra a Tom.',
#  'Get out!\tBájate.',
#  'Get out.\tSalte.',
#  'Get out.\tSal.',
#  'Get out.\tSalí.',
#  'Get out.\tSalid.',
#  'Get out.\tSalgan.',
#  'Go away!\t¡Vete de aquí!',
#  'Go away!\t¡Lárgate!',
#  'Go away!\t¡Salga de aquí!',
#  'Go away!\t¡Largo!',
#  'Go away!\t¡Vete ya!',
#  'Go away!\t¡Órale!',
#  'Go away!\t¡A la calle!',
#  'Go away.\t¡Vete de aquí!',
#  'Go away.\t¡Lárgate!',
#  'Go away.\t¡Largo!',
#  'Go away.\t¡Vete ya!',
#  'Go away.\t¡Órale!',
#  'Go away.\tLárguese.',
#  'Go away.\tVáyase.',
#  'Go home.\tVete a casa.',
#  'Go slow.\tVaya despacio.',
#  'Goodbye!\t¡Hasta luego!',
#  'Goodbye!\tHasta la vista.',
#  'Goodbye!\t¡Chau!',
#  'Hang on!\t¡Espera!',
#  'Hang on!\t¡Espera un momento!',
#  'Hang on!\t¡Un segundo!',
#  'Hang on.\tAgarra fuertemente.',
#  'He came.\tÉl vino.',
#  'He quit.\tÉl renunció.',
#  'Help me!\tAyúdame.',
#  'Help me.\tAyúdame.',
#  'Help me.\tÉchame una mano.',
#  'Help me.\tAyudame.',
#  'Help us.\tAyúdanos.',
#  'Hit Tom.\tGolpea a Tom.',
#  'Hold it!\tEspera.',
#  'Hold on.\tResista.',
#  'Hold on.\tResiste.',
#  'Hold on.\tAgarra fuertemente.',
#  'Hug Tom.\tAbraza a Tom.',
#  'I agree.\tEstoy de acuerdo.',
#  'I agree.\tDe acuerdo.',
#  'I bowed.\tMe incliné.',
#  'I moved.\tMe he mudado.',
#  'I moved.\tMe mudé.',
#  'I moved.\tMe trasladé.',
#  'I moved.\tMe he trasladado.',
#  'I slept.\tDormí.',
#  'I tried.\tLo intenté.',
#  "I'll go.\tIré.",
#  "I'm Tom.\tSoy Tom.",
#  "I'm fat.\tEstoy gordo.",
#  "I'm fat.\tSoy gorda.",
#  "I'm fit.\tEstoy en forma.",
#  "I'm hit!\tEstoy afectado.",
#  "I'm old.\tSoy viejo.",
#  "I'm shy.\tSoy tímido.",
#  "I'm wet.\tEstoy mojada.",
#  "It's OK.\tEstá bien.",
#  "It's me!\tSoy yo.",
#  "It's me.\tSoy yo.",
#  'Join us.\tÚnete a nosotros.',
#  'Join us.\tSé parte nuestra.',
#  'Keep it.\tGuárdalo.',
#  'Me, too.\tYo, también.',
#  'Open up.\tAbre.',
#  'Perfect!\t¡Perfecto!',
#  'See you.\tNos vemos.',
#  'Show me.\tMuéstramelo.',
#  'Show me.\tEnséñamelo.',
#  'Show me.\tMostrame.',
#  'Shut up!\t¡Cierra la boca!',
#  'Shut up!\t¡Cerrá el pico!',
#  'Skip it.\tSáltatelo.',
#  'So long.\tHasta la vista.',
#  'So long.\tHasta luego.',
#  'Stop it.\tPáralo.',
#  'Stop it.\tDeténlo.',
#  'Take it.\tCógelo.',
#  'Tell me.\tDecime.',
#  'Tom ate.\tTom comió.',
#  'Tom ran.\tTom corrió.',
#  'Tom won.\tTom ganó.',
#  'Wait up.\tEspérame despierto.',
#  'Wake up!\t¡Despierta!',
#  'Wake up!\t¡Despiértate!',
#  'Wake up!\t¡Despertate!',
#  'Wake up.\tDespierta.',
#  'Wash up.\tLávate las manos.',
#  'We care.\tNos preocupamos.',
#  'We know.\tLo sabemos.',
#  'We lost.\tPerdimos.',
#  'Welcome.\tBienvenidos.',
#  'Welcome.\tBienvenidas.',
#  'Who ate?\t¿Quién comió?',
#  'Who ran?\t¿Quién corría?',
#  'Who ran?\t¿Quién corrió?',
#  'Who won?\t¿Quién ganó?',
#  'Who won?\t¿Quién ha ganado?',
#  'Why not?\t¿Por qué no?',
#  'You run.\tCorre.',
#  'You won.\tHas ganado.',
#  'Am I fat?\t¿Estoy gordo?',
#  'Ask them.\tPreguntales.',
#  'Ask them.\tPregúntales.',
#  'Back off!\tAparta.',
#  'Back off.\tApártate.',
#  'Be a man.\tSé un hombre.',
#  'Be brave.\tSé fuerte.',
#  'Be brief.\tSé breve.',
#  'Be brief.\tSea breve.',
#  'Be brief.\tSean breves.',
#  'Be quiet.\tEstate quieto.',
#  'Be still.\tNo te muevas.',
#  'Call Tom.\t¡Llamalo a Tomás!',
#  'Call Tom.\t¡Llámalo a Tomás!',
#  'Call Tom.\t¡Llámenlo a Tomás!',
#  'Cheer up!\tAnímate.',
#  'Cheer up.\tVenga.',
#  'Cool off!\t¡Cálmate!',
#  'Cuff him.\tEspósale.',
#  "Don't go.\tNo te vayas.",
#  'Drive on.\tContinúa.',
#  'Find Tom.\tEncontralo a Tomás.',
#  'Find Tom.\tEncuéntralo a Tomás.',
#  'Find Tom.\tEncuéntrelo a Tomás.',
#  'Find Tom.\tEncuéntrenlo a Tomás.',
#  'Find Tom.\tEncuentre a Tom.',
#  'Find Tom.\tEncuentren a Tom.',
#  'Fix this.\tArregla esto.',
#  'Get away!\t¡Vete de aquí!',
#  'Get away!\t¡Lárgate!',
#  'Get away!\t¡Largo!',
#  'Get away!\t¡Vete ya!',
#  'Get down!\tPonte a ello.',
#  'Get down.\tAbajo.',
#  'Get down.\tTúmbate.',
#  'Get lost!\t¡Piérdete!',
#  'Get lost!\t¡Vete de aquí!',
#  'Get lost!\t¡Lárgate!',
#  'Get lost!\t¡Largo!',
#  'Get lost!\t¡Vete ya!',
#  'Get lost.\tEsfúmate.',
#  'Get real!\t¡Despierta!',
#  'Get real!\t¡Piénsalo bien!',
#  'Get real.\tAbre los ojos.',
#  'Go ahead!\tAdelante.',
#  'Go ahead.\tAdelante.',
#  'Go on in.\tEntre.',
#  'Go on in.\tEntra.',
#  'Go on in.\tEntren.',
#  'Go on in.\tEntrá.',
#  'Go on in.\tEntrad.',
#  'Good job!\t¡Buen trabajo!',
#  'Grab Tom.\tSujeta a Tom.',
#  'Grab him.\tAgárralo.',
#  'Have fun.\tDiviértanse.',
#  'Have fun.\tPásala bien.',
#  'Have fun.\tPásenla bien.',
#  'He spoke.\tÉl habló.',
#  'He tries.\tÉl lo intenta.',
#  'He tries.\tÉl prueba.',
#  'Help Tom.\tAyuda a Tom.',
#  'Help him.\tAyúdalo.',
#  'Hi, guys.\tHola, ¿qué hay?',
#  'Hi, guys.\tEy, chavales.',
#  'Hi, guys.\t¿Qué pasa, troncos?',
#  'Hi, guys.\tBuenas.',
#  'Hi, guys.\t¿Qué tal os va?',
#  'Hi, guys.\tHola por aquí.',
#  'How cute!\t¡Qué encanto!',
#  'How deep?\t¿Qué tan profundo?',
#  'How deep?\t¿Cómo de profundo?',
#  'Humor me.\tHazme el favor.',
#  'Humor me.\tCompláceme.',
#  'Hurry up.\t¡Date prisa!',
#  'Hurry up.\tApresúrate.',
#  'I agreed.\tConvine.',
#  'I agreed.\tAcepté.',
#  'I agreed.\tAccedí.',
#  'I am fat.\tSoy gorda.',
#  'I am old.\tEstoy viejo.',
#  'I ate it.\tMe lo comí.',
#  'I ate it.\tMe la comí.',
#  'I can go.\tPuedo ir.',
#  'I did OK.\tLo hice bien.',
#  'I did it.\tLo hice.',
#  'I failed.\tFracasé.',
#  'I forgot.\tLo olvidé.',
#  'I get by.\tMe las arreglo.',
#  'I get it.\tLo entiendo.',
#  'I got it.\tLo tengo.',
#  'I phoned.\tLlamé por teléfono.',
#  'I refuse.\tMe niego.',
#  'I resign.\tDimito.',
#  'I resign.\tRenuncio.',
#  'I saw it.\tLo vi.',
#  'I smiled.\tSonreí.',
#  'I stayed.\tMe quedé.',
#  'I talked.\tHablé.',
#  'I talked.\tHablaba.',
#  'I talked.\tCharlé.',
#  'I talked.\tCharlaba.',
#  'I use it.\tYo lo uso.',
#  'I waited.\tEsperé.',
#  "I'll pay.\tYo pagaré.",
#  "I'm back.\tHe vuelto.",
#  "I'm back.\tEstoy de vuelta.",
#  "I'm bald.\tSoy calvo.",
#  "I'm bald.\tEstoy calvo.",
#  "I'm calm.\tEstoy calmado.",
#  "I'm cool.\tEstoy tranquilo.",
#  "I'm done.\tHe terminado.",
#  "I'm easy.\tSoy bastante facilón.",
#  "I'm fair.\tSoy justo.",
#  "I'm fine.\tEstoy perfectamente.",
#  "I'm free!\t¡Soy libre!",
#  "I'm free.\tYo soy libre.",
#  "I'm full.\tEstoy lleno.",
#  "I'm full.\tEstoy llena.",
#  "I'm full.\tYa me llené.",
#  "I'm here.\tEstoy aquí.",
#  "I'm home.\tEstoy en casa.",
#  "I'm hurt.\tEstoy herido.",
#  "I'm late.\tLlego tarde.",
#  "I'm lazy.\tSoy vago.",
#  "I'm lost.\tEstoy perdida.",
#  "I'm mean.\tSoy malo.",
#  "I'm next.\tMe toca a mí.",
#  "I'm okay.\tEstoy perfectamente.",
#  "I'm poor.\tSoy pobre.",
#  "I'm rich.\tSoy rica.",
#  "I'm rich.\tSoy rico.",
#  "I'm safe.\tEstoy a salvo.",
#  "I'm sick.\tEstoy enferma.",
#  "I'm thin.\tSoy delgado.",
#  "I'm tidy.\tEstoy limpio.",
#  "I'm warm.\tEstoy calentito.",
#  "I'm weak.\tEstoy débil.",
#  "I'm wise.\tSoy listo.",
#  "I've won.\tGané.",
#  'It helps.\tEso ayuda.',
#  'It hurts.\tDuele.',
#  'It works.\tFunciona.',
#  "It's Tom.\tEs Tom.",
#  "It's fun.\tEs divertido.",
#  "It's his.\tEs suyo.",
#  "It's new.\tEs nuevo.",
#  "It's odd.\tEs extraño.",
#  "It's old.\tEs viejo.",
#  "It's red.\tEs rojo.",
#  "It's sad.\tEs triste.",
#  'Keep out!\tProhibido pasar.',
#  'Keep out.\tNo entrar.',
#  'Kiss Tom.\tBesá a Tomás.',
#  'Kiss Tom.\tBesa a Tomás.',
#  'Kiss Tom.\tBesen a Tomás.',
#  'Leave it.\tDéjalo.',
#  'Leave me.\tDéjame.',
#  'Leave us.\tDéjanos.',
#  "Let's go!\tVamos.",
#  "Let's go!\t¡Órale!",
#  'Look out!\tCuidado.',
#  'Marry me.\tCásate conmigo.',
#  'May I go?\t¿Puedo ir?',
#  'Save Tom.\tSalva a Tom.',
#  'She came.\tElla vino.',
#  'She died.\tElla murió.',
#  'She runs.\tElla corre.',
#  'Sit down!\t¡Sentate!',
#  'Sit down.\tSiéntate.',
#  'Sit here.\tSiéntate aquí.',
#  'Speak up!\t¡Hable más fuerte!',
#  'Speak up!\tHabla más fuerte.',
#  'Speak up!\t¡Habla más alto!',
#  'Stand by.\tPrepárate.',
#  'Stand by.\tUn momento.',
#  'Stand up!\t¡Parate!',
#  'Stand up!\t¡De pie!',
#  'Stay put.\tNo te muevas.',
#  'Stop Tom.\tDetén a Tom.',
#  'Take Tom.\tLlévate a Tom.',
#  'Tell Tom.\tDíselo a Tom.',
#  'Terrific!\t¡Genial!',
#  'Terrific!\t¡Órale!',
#  'They won.\tEllos ganaron.',
#  'Tom came.\tTom vino.',
#  'Tom died.\tTom ha muerto.',
#  'Tom fell.\tTom se cayó.',
#  'Tom knew.\tTom lo sabía.',
#  'Tom knew.\tTom tenía constancia de ello.',
#  'Tom left.\tTom se fue.',
#  'Tom lied.\tTom mintió.',
#  'Tom lies.\tTomás miente.',
#  'Tom lost.\tTom perdió.',
#  'Tom paid.\tTom pagó.',
#  'Tom quit.\tTom renunció.',
#  'Tom swam.\tTom nadó.',
#  'Tom wept.\tTom lloró.',
#  "Tom's up.\tTom se ha levantado.",
#  'Too late.\tDemasiado tarde.',
#  'Trust me.\tConfía en mí.',
#  'Try hard.\tInténtalo de veras.',
#  'Try some.\tPrueba un poco.',
#  'Try some.\tPruebe un poco.',
#  'Try some.\tPrueben un poco.',
#  'Try this.\tPrueben esto.',
#  'Try this.\tProbá esto.',
#  'Try this.\tPrueba esto.',
#  'Use this.\tUsa esto.',
#  'Warn Tom.\tAvísale a Tom.',
#  'Warn Tom.\tAvísele a Tom.',
#  'Warn Tom.\tAvísenle a Tom.',
#  'Warn Tom.\tAvisale a Tom.',
#  'Watch me.\tMírame.',
#  'Watch me.\tVigílame.',
#  'Watch me.\tObsérvame.',
#  'Watch us.\tObsérvalos.',
#  'Watch us.\tObsérvanos.',
#  'We agree.\tEstamos de acuerdo.',
#  'We tried.\tLo intentamos.',
#  "We'll go.\tIremos.",
#  "We're OK.\tEstamos bien.",
#  'What for?\t¿Para qué?',
#  'What fun!\t¡Qué divertido!',
#  'Who am I?\t¿Quién soy yo?',
#  'Who came?\t¿Quién vino?',
#  'Who died?\t¿Quién murió?',
#  'Who fell?\t¿Quién se calló?',
#  'Who fell?\t¿Quién se cayó?',
#  'Who quit?\t¿Quién se ha ido?',
#  'Who quit?\t¿Quién lo ha dejado?',
#  'Who swam?\t¿Quién nadó?',
#  "Who's he?\t¿Quién es él?",
#  'Write me.\tEscríbeme.',
#  'After you.\tDespués de ti.',
#  'After you.\tTú primero.',
#  'After you.\tUsted primero.',
#  'After you.\tDespués de usted.',
#  'After you.\tDespués de vosotras.',
#  'Aim. Fire!\tApunta. ¡Fuego!',
#  'Answer me.\tRespóndeme.',
#  'Answer me.\tRespondedme.',
#  'Answer me.\tRespóndanme.',
#  'Birds fly.\tLos pájaros vuelan.',
#  'Bless you.\tJesús.',
#  'Call home!\t¡Llama a casa!',
#  'Calm down.\tCálmate.',
#  'Calm down.\tTranquilízate.',
#  'Calm down.\tTomátelo con soda.',
#  'Calm down.\tBajá un cambio.',
#  'Can we go?\t¿Podemos ir?',
#  'Can we go?\t¿Podemos irnos?',
#  'Can we go?\t¿Podemos marcharnos?',
#  'Catch Tom.\t¡Atrápelo a Tomás!',
#  'Catch him.\tCaptúralo.',
#  'Catch him.\tCaptúrenlo.',
#  'Catch him.\tAtrápenlo.',
#  'Catch him.\tAtrápalo.',
#  'Come back.\tVuelve.',
#  'Come here.\tVení.',
#  'Come here.\tVen.',
#  'Come here.\tVenid aquí.',
#  'Come home.\tVen a casa.',
#  'Come over.\tVenid aquí.',
#  'Come over.\tVente.',
#  'Come over.\tVeníos.',
#  'Come over.\tVenga aquí.',
#  'Come soon.\tVuelve pronto.',
#  'Do it now.\tHazlo ahora.',
#  'Dogs bark.\tLos perros ladran.',
#  "Don't ask.\tNo preguntes.",
#  "Don't cry.\tNo llores.",
#  "Don't cry.\t¡No llorés!",
#  "Don't cry.\t¡No llores!",
#  "Don't cry.\tNo lloren.",
#  "Don't lie.\tNo mintáis.",
#  "Don't run.\tNo corras.",
#  'Fantastic!\t¡Fantástico!',
#  'Fantastic!\t¡Es estupendo!',
#  'Fantastic!\t¡Órale!',
#  'Feel this.\tTienta esto.',
#  'Feel this.\tTiente esto.',
#  'Feel this.\tTienten esto.',
#  'Feel this.\tTentad esto.',
#  'Feel this.\tTentá esto.',
#  'Follow me.\tSígueme.',
#  'Follow me.\tSeguidme.',
#  'Follow us.\tSíguenos.',
#  'Forget it.\tDéjalo.',
#  'Forget me.\tOlvídame.',
#  'Forget me.\tOlvídate de mí.',
#  'Forget me.\tOlvídenme.',
#  'Forget me.\tOlvídense de mí.',
#  'Get ready.\tPreparaos.',
#  'Go for it.\tVe a por ello.',
#  'Go for it.\tVe a cogerlo.',
#  'Go get it.\tVe a por ello.',
#  'Go get it.\tVete a por ello.',
#  'Go get it.\tId a por ello.',
#  'Go inside.\tEntra.',
#  'Go to bed.\tVete a la cama.',
#  'Grab that.\tCógelo.',
#  'Grab this.\tAgarra esto.',
#  'Have some.\tCoge alguno.',
#  'Have some.\tToma algo.',
#  'Have some.\tTome alguno.',
#  'He is old.\tÉl es viejo.',
#  'He is old.\tÉl es anciano.',
#  'He shaved.\tÉl se afeitó.',
#  'He smiled.\tSonrió.',
#  "He's a DJ.\tÉl es DJ.",
#  "He's fast.\tÉl es veloz.",
#  "He's good.\tÉl es bueno.",
#  "He's rich.\tÉl es rico.",
#  "He's rich.\tEs rico.",
#  'Here I am.\tAcá estoy.',
#  'Hold this.\tSostén esto.',
#  'How awful!\t¡Qué horror!',
#  'How weird!\t¡Qué raro!',
#  "How's Tom?\t¿Cómo está Tom?",
#  'Humor Tom.\tDivierte a Tom.',
#  'I am busy.\tEstoy ocupada.',
#  'I am full.\tEstoy lleno.',
#  'I am full.\tEstoy llena.',
#  'I am good.\tSoy bueno.',
#  'I am here.\tEstoy aquí.',
#  'I am sick.\tEstoy enferma.',
#  'I am weak.\tEstoy débil.',
#  'I beg you.\tTe lo ruego.',
#  'I beg you.\tTe lo suplico.',
#  'I can fly.\tPuedo volar.',
#  'I can run.\tPuedo correr.',
#  'I can run.\tSé correr.',
#  'I can ski.\tSé esquiar.',
#  'I cringed.\tSentí vergüenza.',
#  'I fainted.\tPerdí la consciencia.',
#  'I fainted.\tQuedé inconsciente.',
#  'I gave up.\tLo dejé.',
#  'I gave up.\tMe rendí.',
#  'I gave up.\tTiré la toalla.',
#  'I gave up.\tCedí.',
#  'I get you.\tTe entiendo.',
#  'I get you.\tTe pillo.',
#  'I get you.\tYa te pillo.',
#  'I got hit.\tMe dieron.',
#  'I got hit.\tMe alcanzaron.',
#  'I hate it.\tLo odio.',
#  'I hate it.\tMe la seca.',
#  'I hate it.\tMe la baja.',
#  'I hit Tom.\tGolpeo a Tom.',
#  'I hope so.\tEso espero.',
#  'I knew it.\tLo sabía.',
#  'I laughed.\tMe reí.',
#  'I like it.\tMe gusta.',
#  'I love it!\t¡Lo adoro!',
#  'I love it.\tMe encanta.',
#  'I mean it!\tHablo en serio.',
#  'I mean it.\tLo digo en serio.',
#  'I mean it.\tHablo en serio.',
#  'I miss it.\tLo echo en falta.',
#  'I miss it.\tLo echo de menos.',
#  'I miss it.\tLo añoro.',
#  'I need it.\tLo necesito.',
#  'I saw Tom.\tVi a Tom.',
#  'I saw him.\tLe vi.',
#  'I saw him.\tLo vi.',
#  'I saw one.\tVi uno.',
#  'I saw one.\tVi a uno.',
#  'I saw one.\tVeía a uno.',
#  'I saw you.\tTe vi.',
#  'I saw you.\tTe he visto.',
#  'I see Tom.\tVeo a Tom.',
#  'I tripped.\tMe tropecé.',
#  "I'll cook.\tYo cocinaré.",
#  "I'll cook.\tYo guisaré.",
#  "I'll live.\tViviré.",
#  "I'll sing.\tCantaré.",
#  "I'll stop.\tPararé.",
#  "I'll stop.\tLo dejaré.",
#  "I'll wait.\tEsperaré.",
#  "I'll wait.\tAguardaré.",
#  "I'll walk.\tCaminaré.",
#  "I'll walk.\tAndaré.",
#  "I'll work.\tVoy a trabajar.",
#  "I'm a man.\tSoy un hombre.",
#  "I'm a pro.\tSoy un pro.",
#  "I'm alone.\tEstoy solo.",
#  "I'm alone.\tEstoy sola.",
#  "I'm alone.\tYo estoy solo.",
#  "I'm alone.\tYo estoy sola.",
#  "I'm angry.\tEstoy enojado.",
#  "I'm angry.\tEstoy enojada.",
#  "I'm awake.\tEstoy despierto.",
#  "I'm blind.\tSoy ciega.",
#  "I'm broke.\tEstoy sin dinero.",
#  "I'm broke.\tEstoy quebrado.",
#  "I'm broke.\tEstoy sin blanca.",
#  "I'm broke.\tNo tengo blanca.",
#  "I'm crazy.\tEstoy loco.",
#  "I'm drunk.\tEstoy borracho.",
#  "I'm drunk.\tEstoy tomada.",
#  "I'm drunk.\tEstoy prendida.",
#  "I'm dying.\tMe estoy muriendo.",
#  "I'm first.\tSoy el primero.",
#  "I'm first.\tVoy el primero.",
#  "I'm first.\tMe toca primero.",
#  "I'm first.\tYo voy primero.",
#  "I'm happy.\tSoy feliz.",
#  "I'm happy.\tEstoy feliz.",
#  "I'm loved.\tSoy amado.",
#  "I'm loved.\tSoy amada.",
#  "I'm obese.\tSoy obeso.",
#  "I'm ready.\tEstoy listo.",
#  "I'm sorry.\tLo siento.",
#  "I'm tired.\tYo estoy cansado.",
#  "I'm tired.\tYo estoy cansada.",
#  "I'm yours.\tSoy tuyo.",
#  "I'm yours.\tSoy tuya.",
#  "I'm yours.\tSoy suyo.",
#  "I've lost.\tHe perdido.",
#  'Ignore it.\tÓlvidalo.',
#  'Ignore it.\tNo hagas caso.',
#  'Is Tom OK?\t¿Está bien Tom?',
#  'Is Tom in?\t¿Está Tom?',
#  'Is it bad?\t¿Es grave?',
#  'Is it bad?\t¿Es malo?',
#  'Is it far?\t¿Está lejos?',
#  'Is it you?\t¿Eres tú?',
#  'It burned.\tSe quemó.',
#  'It failed.\tNo lo consiguió.',
#  'It failed.\tFalló.',
#  'It failed.\tFracasó.',
#  'It is new.\tEs nuevo.',
#  'It rained.\tLlovió.',
#  'It snowed.\tNevó.',
#  'It stinks.\tApesta.',
#  'It worked.\tFuncionó.',
#  "It's 3:10.\tSon las tres y diez.",
#  "It's 8:30.\tSon las 8:30.",
#  "It's a TV.\tEs un televisor.",
#  "It's cold.\tHace frío.",
#  "It's cold.\tEstá frío.",
#  "It's cool.\tEstá frío.",
#  "It's cool.\tEstá fresco.",
#  "It's dark.\tEstá oscuro.",
#  "It's done!\t¡Está listo!",
#  "It's fine.\tEstá perfecto.",
#  "It's good.\tEstá bien.",
#  "It's good.\tEs bueno.",
#  "It's here.\tEstá aquí.",
#  "It's hers.\tEs de ella.",
#  "It's late.\tEs tarde.",
#  "It's mine.\tEs mío.",
#  "It's mine.\tEs mía.",
#  "It's nice.\tEs agradable.",
#  "It's nice.\tHace buen tiempo.",
#  "It's okay.\tVale.",
#  "It's okay.\tEstá bien.",
#  "It's ours.\tEs nuestro.",
#  "It's ours.\tEs la nuestra.",
#  "It's over.\tSe terminó.",
#  "It's over.\tSe acabó.",
#  "It's time.\tHa llegado el momento.",
#  "It's time.\tEs la hora.",
#  "It's time.\tEs el momento.",
#  "It's time.\tHa llegado la hora.",
#  "It's true!\t¡Es verdad!",
#  "It's true.\tEs verdad.",
#  "It's work.\tEs mi trabajo.",
#  'Keep them.\tGuárdalos.',
#  'Keep them.\tQuédatelos.',
#  'Keep them.\tGuárdenselos.',
#  'Keep this.\tGuarda esto.',
#  'Keep this.\tGuarde esto.',
#  'Keep this.\tGuardá esto.',
#  'Keep this.\tGuardad esto.',
#  'Keep this.\tGuarden esto.',
#  'Keep warm.\tMantente caliente.',
#  'Keep warm.\tManténgase caliente.',
#  'Keep warm.\tMantenete caliente.',
#  'Keep warm.\tMantenete abrigado.',
#  'Keep warm.\tMantente abrigado.',
#  'Keep warm.\tManténgase abrigado.',
#  'Keep warm.\tManténganse calientes.',
#  'Keep warm.\tManténganse abrigados.',
#  'Leave Tom.\tDejalo a Tomás.',
#  'Leave Tom.\tDéjalo a Tomás.',
#  'Leave Tom.\tDéjelo a Tomás.',
#  'Leave now.\tAhora márchate.',
#  'Leave now.\tAhora vete.',
#  'Leave now.\tAhora lárgate.',
#  'Let me go!\t¡Déjame marchar!',
#  'Let me go!\t¡Suéltame!',
#  'Let me go!\t¡Déjeme ir!',
#  'Let me go.\t¡Déjeme ir!',
#  'Let me in.\tDéjame entrar.',
#  'Let me in.\tDéjeme entrar.',
#  'Let us in.\tDéjanos entrar.',
#  "Let's eat.\tComamos.",
#  "Let's see.\tVeamos.",
#  "Let's try!\t¡Intentémoslo!",
#  'Lie still.\tTúmbate en silencio.',
#  'Lie still.\tMantente quieto en el suelo.',
#  'Listen up.\tEscuchá.',
#  'Look away.\tMirá para otro lado.',
#  'Look away.\tMira para otro lado.',
#  'Look away.\tMire para otro lado.',
#  'Look away.\tMiren para otro lado.',
#  'Look back!\t¡Mira hacia atrás!',
#  'Look back.\tMira atrás.',
#  'Look back.\tMire atrás.',
#  'Look back.\tMirad atrás.',
#  'Look here.\tMira aquí.',
#  'Look here.\tMirad aquí.',
#  'Look here.\tMiren aquí.',
#  'Loosen it.\tAflójalo.',
#  'Loosen it.\tSuéltalo.',
#  'Loosen it.\tSuéltala.',
#  'Loosen it.\tAflójala.',
#  'Move over.\tHazte a un lado.',
#  'Move over.\tDeja sitio.',
#  'Move over.\tMueve el culo.',
#  'Move over.\tDeja pasar.',
#  'Nice shot!\t¡Buen tiro!',
#  'Of course!\t¡Por supuesto!',
#  'Open fire!\t¡Disparad!',
#  'Open fire!\t¡Fuego a discreción!',
#  'Pardon me?\t¿Perdona?',
#  'Please go.\tPor favor, ve.',
#  'Please go.\tPor favor, vete.',
#  'Please go.\tPor favor, márchate.',
#  'Please go.\tPor favor, váyase.',
#  'Put it on.\tPóntelo.',
#  'Put it on.\tPóngaselo.',
#  'Read this.\tLee esto.',
#  'Read this.\tLea esto.',
#  'Read this.\tLean esto.',
#  'Read this.\tLeed esto.',
#  'Say hello.\tDecí hola.',
#  'Search me.\tA mí que me registren.',
#  'See above.\tVéase arriba.',
#  'See above.\tVéase más arriba.',
#  'Seize him!\t¡A por él!',
#  'Seize him!\t¡Cogedlo!',
#  'Seize him!\t¡Arrestadlo!',
#  'Seize him!\t¡Prendedlo!',
#  'Seize him!\t¡Capturadlo!',
#  'Seriously?\t¿En serio?',
#  'She tried.\tElla lo intentó.',
#  'She tried.\tElla lo probó.',
#  'She walks.\tElla anda.',
#  'She walks.\tElla camina.',
#  'She walks.\tAnda.',
#  "She's hot.\tElla es candente.",
#  "She's hot.\tEstá como un tren.",
#  "She's hot.\tEstá de toma pan y moja.",
#  "She's hot.\tEstá buena.",
#  "She's hot.\tEstá que cruje.",
#  'Sign here.\tFirme aquí.',
#  'Sign this.\tFirma esto.',
#  'Sign this.\tFirme esto.',
#  'Sign this.\tFirmen esto.',
#  'Sign this.\tFirmá esto.',
#  'Sign this.\tFirmad esto.',
#  'Sit still.\tSiéntate y no te muevas.',
#  'Sit still.\tSiéntate y quédate quieto.',
#  'Sit there.\tSentate ahí.',
#  'Sit tight.\tTú mantente.',
#  'Slow down.\tQuieto.',
#  'Slow down.\tMás despacio.',
#  'Stay away.\tFuera.',
#  'Stay away.\tAléjate.',
#  'Stay calm.\tMantén la calma.',
#  'Stay calm.\tMantené la calma.',
#  'Stay here.\tQuedate acá.',
#  'Step back.\tDa un paso atrás.',
#  'Stop here.\tPara aquí.',
#  'Stop here.\tPárate aquí.',
#  'Stop here.\tDetente aquí.',
#  'Stop here.\tDeténgase aquí.',
#  'Stop here.\tDeténganse aquí.',
#  'Stop here.\tParaos aquí.',
#  'Stop here.\tParad aquí.',
#  'Stop that.\tPara eso.',
#  'Stop them.\tDeténlos.',
#  'Stop them.\tPárales.',
#  'Take care!\t¡Cuidate!',
#  'Take care!\t¡Te cuidas!',
#  'Take care.\tCuídate.',
#  'Take care.\tCuidaos.',
#  'Take mine.\tCoge el mío.',
#  'Take mine.\tToma el mío.',
#  'Take over.\tAsume el mando.',
#  'Take over.\tToma el control.',
#  'Take over.\tEncárgate tú.',
#  'Take this.\tToma esto.',
#  'Take this.\tTome esto.',
#  'Take this.\tTomen esto.',
#  'Take this.\tTomá esto.',
#  'Thank you.\t¡Gracias!',
#  'Thank you.\tGracias a ti.',
#  'Thank you.\tGracias.',
#  "That's it.\tEso es.",
#  "That's me.\tSoy yo.",
#  "That's me.\tEse soy yo.",
#  'Then what?\t¿Entonces qué?',
#  'They fell.\tCayeron.',
#  'They left.\tSe fueron.',
#  'They left.\tSe marcharon.',
#  'They left.\tSe iban.',
#  'They lost.\tPerdieron.',
#  'Tom bowed.\tTom se inclinó.',
#  'Tom cared.\tTom se preocupó.',
#  'Tom cared.\tTom se preocupaba.',
#  'Tom cared.\tA Tom le importaba.',
#  'Tom cares.\tTom se preocupa.',
#  'Tom cares.\tA Tom le importa.',
#  'Tom cried.\tTom lloró.',
#  'Tom dozed.\tTom dormitó.',
#  'Tom drove.\tTomás condujo.',
#  'Tom is OK.\tTom está bien.',
#  'Tom is in.\tTom está dentro.',
#  'Tom is up.\tTom está levantado.',
#  'Tom knits.\tTom teje.',
#  'Tom knows.\tTom sabe.',
#  'Tom moved.\tTom se mudó.',
#  'Tom moved.\tTom se movió.',
#  'Tom rocks.\tTom se mece.',
#  'Tom stood.\tTom se quedó.',
#  'Tom swims.\tTom nada.',
#  'Tom swore.\tTom juró.',
#  'Tom tried.\tTomás lo intentó.',
#  'Tom tries.\tTomás lo intenta.',
#  'Tom voted.\tTomás votó.',
#  'Tom walks.\tTom camina.',
#  'Tom waved.\tTom saludó.',
#  'Tom works.\tTomás trabaja.',
#  "Tom'll go.\tTom irá.",
#  "Tom's fat.\tTom está gordo.",
#  "Tom's mad.\tTom está loco.",
#  "Tom's sad.\tTom está triste.",
#  "Tom's shy.\tTom es tímido.",
#  'Trust Tom.\tConfía en Tom.',
#  'Try again.\tInténtalo de nuevo.',
#  'Try again.\tIntentadlo otra vez.',
#  'Try again.\tIntenta otra vez.',
#  'Try it on.\tPruébatelo.',
#  'Wait here.\tEspera aquí.',
#  'Wait here.\tAguarda aquí.',
#  'Wait here.\tEsperen aquí.',
#  'Wait here.\tEsperad aquí.',
#  'Watch Tom.\tVigila a Tom.',
#  'Watch out!\t¡Abusado!',
#  'We can go.\tPodemos ir.',
#  'We can go.\tPodemos irnos.',
#  'We can go.\tNos podemos marchar.',
#  'We failed.\tFallamos.',
#  'We failed.\tHemos fallado.',
#  'We forgot.\tNos olvidamos.',
#  'We saw it.\tLo vimos.',
#  'We saw it.\tLo veíamos.',
#  'We talked.\tConversamos.',
#  'We waited.\tNosotros esperamos.',
#  "We'll see.\tDespués veremos.",
#  "We'll see.\tYa veremos.",
#  "We'll try.\tLo intentaremos.",
#  "We've won!\t¡Hemos ganado!",
#  "What's up?\t¿Qué hay?",
#  'Who cares?\t¿A quién le importa?',
#  'Who is he?\t¿Quién es él?',
#  'Who is it?\t¿Quién es?',
#  'Who knows?\tAabe...',
#  'Who stood?\t¿Quién se quedó?',
#  "Who'll go?\t¿Quién irá?",
#  "Who's Tom?\t¿Quién es Tom?",
#  'Write Tom.\tEscribe a Tom.',
#  'You drive.\tTú maneja.',
#  'You start.\tTú empieza.',
#  'You tried.\tLo intentaste.',
#  "You're OK.\tTú estás perfectamente.",
#  "You're OK.\tEstás perfectamente.",
#  'Aim higher.\tMás alto.',
#  'Aim higher.\tApuntad más alto.',
#  'All aboard!\t¡Todos a bordo!',
#  'Am I right?\t¿Tengo razón?',
#  'Am I wrong?\t¿Me equivoco?',
#  'Am I wrong?\t¿Estoy equivocada?',
#  'Answer Tom.\t¡Respóndale a Tomás!',
#  'Answer Tom.\t¡Respondele a Tomás!',
#  'Answer Tom.\t¡Respóndanle a Tomás!',
#  'Are you 18?\t¿Tienes dieciocho?',
#  'Are you 18?\t¿Has cumplido dieciocho?',
#  'Are you OK?\t¿Estás bien?',
#  'Are you in?\t¿Te apuntas?',
#  'Are you in?\t¿Estás dentro?',
#  'Are you up?\t¿Estás levantado?',
#  'Ask anyone.\tPregúntale a cualquiera.',
#  'Ask anyone.\tPreguntadle a cualquiera.',
#  'Ask anyone.\tPregúntele a cualquiera.',
#  'Ask anyone.\tPregúntenle a cualquiera.',
#  'Ask around.\tPregunta por aquí.',
#  'Ask around.\tPregunta en los alrededores.',
#  'Be careful.\t¡Ten cuidado!',
#  'Be careful.\t¡Sé cuidadoso!',
#  'Be content.\tEstate contento.',
#  'Be on time.\tLlega a tiempo.',
#  'Be on time.\tLlegue a tiempo.',
#  'Be patient.\tSea paciente.',
#  'Be serious.\tSé serio.',
#  'Birds sing.\tLos pájaros cantan.',
#  'Birds sing.\tLos pájaros están cantando.',
#  'Bring food.\tTraed comida.',
#  'Bring help.\tTraed ayuda.',
#  'Bring wine.\tTrae vino.',
#  'Can I come?\t¿Puedo ir?',
#  'Can I come?\t¿Puedo venir?',
#  'Can I come?\t¿Puedo acercarme?',
#  'Can I help?\t¿Puedo ayudar?',
#  'Can I stay?\t¿Me puedo quedar?',
#  'Carry this.\tLleva esto.',
#  'Check that.\tComprobad eso.',
#  'Check this.\tComprueba esto.',
#  'Choose one.\tEscoge uno.',
#  'Come again.\tVuelve otra vez.',
#  'Come alone.\tVen solo.',
#  'Come along.\tVente.',
#  'Come along.\tVénganse.',
#  'Come early.\tVení temprano.',
#  'Come early.\tVen temprano.',
#  'Come early.\tVengan temprano.',
#  'Come early.\tVenga temprano.',
#  'Come on in!\t¡Pásale!',
#  'Come on in!\t¡Pásele!',
#  'Come on in!\t¡Pásenle!',
#  'Come on in.\tEntre.',
#  'Come on in.\tPase.',
#  'Come quick!\t¡Ven rápido!',
#  'Come quick!\t¡Vení rápido!',
#  'Come to me.\tVen a mí.',
#  'Come to me.\tVenid a mí.',
#  'Come to us.\tVen a nosotros.',
#  'Come to us.\tVenid a nosotros.',
#  'Cut it out!\t¡Ya párale!',
#  'Did Tom go?\t¿Fue Tom?',
#  'Do come in!\t¡Pásale!',
#  'Do come in!\t¡Pásele!',
#  'Do come in!\t¡Pásenle!',
#  'Do come in.\tPasa adentro.',
#  'Do come in.\tEntra de una vez.',
#  'Do come in.\tEntra ya.',
#  'Do come in.\tMétete dentro.',
#  'Do men cry?\t¿Los hombres lloran?',
#  "Don't come.\tNo vengas.",
#  "Don't jump!\t¡No saltéis!",
#  "Don't look.\tNo miréis.",
#  "Don't move!\t¡No os mováis!",
#  "Don't move.\tNo te muevas.",
#  "Don't move.\tNo se mueva.",
#  "Don't move.\tNo se muevan.",
#  "Don't sing.\tNo cantes.",
#  "Don't sing.\tNo canten.",
#  "Don't stop.\tNo pares.",
#  "Don't talk!\t¡No hables!",
#  "Don't talk.\tNo hables.",
#  "Don't wait.\t¡No esperes!",
#  "Don't wait.\t¡No esperen!",
#  "Don't wait.\tNo esperes.",
#  "Don't yell.\tNo grites.",
#  'Eat slowly.\tCome despacio.',
#  'Eat slowly.\t¡Comé despacio!',
#  'Fire burns.\tEl fuego quema.',
#  'Follow Tom.\tSeguilo a Tomás.',
#  'Follow Tom.\tSíguelo a Tomás.',
#  'Follow Tom.\tSígalo a Tomás.',
#  'Follow Tom.\tSíganlo a Tomás.',
#  'Follow him.\tSíguele.',
#  'Follow him.\tSíguelo.',
#  'Forget Tom.\tOlvidate de Tomás.',
#  'Forget Tom.\tOlvídate de Tomás.',
#  'Forget Tom.\tOlvídese de Tomás.',
#  'Forget him.\tOlvídenlo.',
#  'Forgive us.\tPerdónanos.',
#  'Forgive us.\tPerdónenos.',
#  'Get a life.\tConsíguete una vida.',
#  'Get inside.\tEntra.',
#  'Get to bed.\tVete a la cama.',
#  'Give it up.\tDéjalo.',
#  'Go on home.\tVete a casa.',
#  'Go on home.\tVáyase a casa.',
#  'Go see Tom.\tVe a ver a Tom.',
#  'Go to work.\tAndá a trabajar.',
#  'God exists.\tDios existe.',
#  'Have faith.\tTen fe.',
#  'Have faith.\tTened fe.',
#  'Have faith.\tTengan fe.',
#  'Have faith.\tConfíen.',
#  'He ate out.\tÉl salió a comer.',
#  'He coughed.\tTosió.',
#  'He gave in.\tÉl se rindió.',
#  'He gave up.\tSe rindió.',
#  'He gave up.\tLo dejó.',
#  'He gave up.\tCedió.',
#  'He gave up.\tTiró la toalla.',
#  'He hung up.\tDescolgó.',
#  'He hung up.\tÉl cogió el teléfono.',
#  ...]

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='') # 这个可是个好玩意，将文本映射为编码 只不过无法处理tensor
  lang_tokenizer.fit_on_texts(lang) # fit

  tensor = lang_tokenizer.texts_to_sequences(lang) #将文本映射成词

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
# Try experimenting with the size of that dataset
num_examples = 30000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
print(input_tensor)
print(inp_lang.index_word)
# Out:
# [[   1  135    3 ...    0    0    0]
#  [   1  293    3 ...    0    0    0]
#  [   1  595    3 ...    0    0    0]
#  ...
#  [   1   18 9413 ...    0    0    0]
#  [   1   63 2490 ...    0    0    0]
#  [   1   23 2175 ...    0    0    0]]
# {1: '<start>', 2: '<end>', 3: '.', 4: 'tom', 5: '?', 6: '¿', 7: 'es', 8: 'no', 9: 'el', 10: 'a', 11: 'que', 12: 'me', 13: 'la', 14: 'de', 15: 'un', 16: 'esta', 17: 'se', 18: 'lo', 19: 'mi', 20: 'en', 21: 'una', 22: 'por', 23: 'te', 24: 'estoy', 25: 'ella', 26: 'yo', 27: '!', 28: 'eso', 29: 'le', 30: 'esto', 31: 'tu', 32: ',', 33: 'los', 34: 'aqui', 35: 'soy', 36: 'muy', 37: 'tengo', 38: 'puedo', 39: 'las', 40: 'gusta', 41: 'mary', 42: 'tiene', 43: 'son', 44: 'con', 45: 'como', 46: 'quien', 47: 'estaba', 48: 'su', 49: 'este', 50: 'favor', 51: 'estas', 52: 'eres', 53: 'quiero', 54: 'ellos', 55: 'fue', 56: 'bien', 57: 'casa', 58: 'ahora', 59: 'tomas', 60: 'donde', 61: 'mas', 62: 'estan', 63: 'nos', 64: 'he', 65: 'solo', 66: 'puede', 67: 'ha', 68: 'era', 69: 'todos', 70: 'al', 71: 'para', 72: 'ir', 73: 'tan', 74: 'todo', 75: 'estamos', 76: 'necesito', 77: 'ya', 78: 'nadie', 79: 'puedes', 80: 'trabajo', 81: 'voy', 82: 'usted', 83: 'tienes', 84: 'demasiado', 85: 'ese', 86: 'nada', 87: 'y', 88: 'hay', 89: 'mucho', 90: 'nunca', 91: 'hizo', 92: 'perro', 93: 'esa', 94: 'algo', 95: 'libro', 96: 'hoy', 97: 'poco', 98: 'dos', 99: 'parece', 100: 'todavia', 101: 'dinero', 102: 'tiempo', 103: 'nuevo', 104: 'sabe', 105: 'somos', 106: 'quiere', 107: 'mis', 108: 'gustan', 109: 'ser', 110: 'nosotros', 111: 'vez', 112: 'coche', 113: 'estar', 114: 'sos', 115: 'feliz', 116: 'va', 117: 'buen', 118: 'tarde', 119: 'ti', 120: 'ahi', 121: 'frances', 122: 'hablar', 123: 'hacer', 124: 'verdad', 125: 'hace', 126: 'creo', 127: 'tenemos', 128: 'ayuda', 129: 'alli', 130: 'boston', 131: 'hombre', 132: 'has', 133: 'deja', 134: 'vi', 135: 've', 136: 'mal', 137: 'alguien', 138: 'auto', 139: 'vamos', 140: 'si', 141: 'mejor', 142: 'siento', 143: 'podria', 144: 'podemos', 145: 'cuando', 146: 'hice', 147: 'vida', 148: 'odio', 149: 'dia', 150: 'conmigo', 151: 'siempre', 152: 'les', 153: 'encanta', 154: 'otra', 155: 'dejame', 156: 'rapido', 157: 'cual', 158: 'ustedes', 159: 'vino', 160: 'tenia', 161: 'puerta', 162: 'bueno', 163: 'ver', 164: 'hacerlo', 165: 'ven', 166: 'tambien', 167: 'os', 168: 'comer', 169: 'buena', 170: 'sus', 171: 'deberia', 172: 'dijo', 173: 'listo', 174: 'padre', 175: 'habitacion', 176: 'habla', 177: 'nuestro', 178: 'realmente', 179: 'ayudar', 180: 'queria', 181: 'hecho', 182: 'mismo', 183: 'nadar', 184: 'cansado', 185: 'ocupado', 186: 'del', 187: 'acabo', 188: 'razon', 189: 'grande', 190: 'noche', 191: 'gracias', 192: 'mira', 193: 'gato', 194: 'miedo', 195: 'manana', 196: 'acuerdo', 197: 'debo', 198: 'cama', 199: 'dije', 200: 'tus', 201: 'espera', 202: 'visto', 203: 'mio', 204: 'tal', 205: 'bastante', 206: 'alto', 207: 'veo', 208: 'ellas', 209: 'necesita', 210: 'dame', 211: 'idea', 212: 'amigos', 213: 'hemos', 214: 'quieres', 215: 'pareces', 216: 'casi', 217: 'estado', 218: 'fui', 219: 'hambre', 220: 'dio', 221: 'agua', 222: 'sabes', 223: 'sabia', 224: 'uno', 225: 'comida', 226: 'problema', 227: 'facil', 228: 'frio', 229: 'fuera', 230: 'lunes', 231: 'amigo', 232: 'duele', 233: 'dejo', 234: 'conozco', 235: 'estos', 236: 'vio', 237: 'madre', 238: 'pronto', 239: 'anos', 240: 'nino', 241: 'loco', 242: 'haz', 243: 'dormir', 244: 'libros', 245: 'puso', 246: 'mano', 247: 'sin', 248: 'television', 249: 'vive', 250: 'ojos', 251: 'menos', 252: 'cantar', 253: 'estuvo', 254: 'hora', 255: 'enfermo', 256: 'amo', 257: 'seguro', 258: 'mundo', 259: 'tienen', 260: 'pelo', 261: 'murio', 262: 'perros', 263: 'perdido', 264: 'joven', 265: 'compre', 266: 'mujer', 267: 'maria', 268: 'nombre', 269: 'contigo', 270: 'viejo', 271: 'hablo', 272: 'triste', 273: 'entrar', 274: 'espero', 275: 'sueno', 276: 'suerte', 277: 'necesitamos', 278: 'estais', 279: 'haciendo', 280: 'reloj', 281: 'perdi', 282: 'hasta', 283: 'momento', 284: 'toma', 285: 'tres', 286: 'queremos', 287: 'sigue', 288: 'viene', 289: 'escuela', 290: 'llave', 291: 'culpa', 292: 'historia', 293: 'vete', 294: 'fuerte', 295: 'calor', 296: 'vas', 297: 'cafe', 298: 'gran', 299: 'temprano', 300: 'cerca', 301: 'cerveza',  ...

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 24000 24000 6000 6000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 4 ----> tom
# 104 ----> sabe
# 11 ----> que
# 41 ----> mary
# 903 ----> mintio
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 5 ----> tom
# 200 ----> knows
# 45 ----> mary
# 548 ----> lied
# 3 ----> .
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 16]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 16, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # 这个 query代表的就是最后一次输入，values代表的就是之前的那些个hidden layers输出
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    # dense层都是对最后一个轴作为一批的输入，然后计算一个unit大小的轴
    # self.W1(query_with_time_axis)输出形状是(batch_size, 1, units)
    # self.W2(values)输出形状是(batch_size, max_len, units)
    # print(self.W1(query_with_time_axis).shape)
    # print(self.W2(values).shape)
    # print(tf.nn.tanh(
    #     self.W1(query_with_time_axis) + self.W2(values)).shape)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values # 这个的输出是(batch_size, max_len, hidden size)
    # print(context_vector.shape)
    context_vector = tf.reduce_sum(context_vector, axis=1) # 在sequence这个axis上求和，相当于对每个隐向量加权求和了

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 16, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # hidden是当前decoder的隐向量，相当于状态，x是当前的输入词，是一个(batch_size,1)的东西
    # enc_output是encoder的输出用于计算注意力
    # enc_output shape == (batch_size, max_length, hidden_size)
    # context_vector的形状是(batch_size,attention_units)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 4935)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  """

  :param real: (batch_size,)  相当于整个batch里第t个词的数据
  :param pred: (batch_size,vocab_size)
  :return:
  """
  print(real.shape)
  print(pred.shape)
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  # 为啥需要有这一步呢，这是因为如果target 为0，那这个词就是空词，不该算损失的。
  print(mask)
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
mask = tf.math.logical_not(tf.math.equal([0,1], 0))
tf.cast(mask, dtype=tf.float32)
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([0., 1.], dtype=float32)>

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  # 输入就是一个batch
  loss = 0

  with tf.GradientTape() as tape:
    # 一次吧一个batch的文字序列喂给encoder得到完整的hidden状态
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden
    # 一次输入一列的word，dec_input记录的就是整个batch里第t个词的数据，喂给decoder
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)
  print(targ.shape)
  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 10

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
    break
  break
  # saving (checkpoint) the model every 2 epochs
  # if (epoch + 1) % 2 == 0:
  #   checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# (64,)
# (64, 4935)
# Tensor("LogicalNot:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_1:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_2:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_3:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_4:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_5:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_6:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_7:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_8:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_9:0", shape=(64,), dtype=bool)
# (64, 11)
# (64,)
# (64, 4935)
# Tensor("LogicalNot:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_1:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_2:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_3:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_4:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_5:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_6:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_7:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_8:0", shape=(64,), dtype=bool)
# (64,)
# (64, 4935)
# Tensor("LogicalNot_9:0", shape=(64,), dtype=bool)
# (64, 11)
# Epoch 1 Batch 0 Loss 4.1672

# %%
targ[:, 1]
# Out:
# <tf.Tensor: shape=(64,), dtype=int32, numpy=
# array([  13,   20,    4,    4,   62,    4,    4, 1550,   25,    6,    4,
#         132,   57,    4,  882,    4,   20,   30,   27,    4,  279,   86,
#          28,   86,   27,    6,   24,   25,    5,    5,    4,    4,   24,
#         267,    5,   10,   88,    6,   94,    6,   61,   24,   25,  157,
#          27,    5,   22,  403,   21,    4,  188,   53,   10,    5,   13,
#          14,    4,   13,    4,   16,    4,    4,   56,    4], dtype=int32)>
